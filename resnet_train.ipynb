# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/CompVision-Course')

# %%
import resnet
from cifar_prepr import *

# %%
net = resnet.ResNet([3, 3, 3, 3])

# %%
X_train, y_train, X_test, y_test = get_cifar()
# Out:
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# ...
# 170500096it [00:01, 87752475.57it/s]
# Files already downloaded and verified

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
net = net.to(device)

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
accuracies, losses = resnet.fit(net, X_train, y_train, X_test, y_test, 30)
# Out:
# Epoch: 0	Time 27.433
# Loss 1.298	Accuracy 0.544
# Epoch: 1	Time 56.801
# Loss 1.110	Accuracy 0.619
# Epoch: 2	Time 85.666
# Loss 1.067	Accuracy 0.636
# Epoch: 3	Time 114.171
# Loss 0.945	Accuracy 0.688
# Epoch: 4	Time 142.918
# Loss 0.947	Accuracy 0.675
# Epoch: 5	Time 171.685
# Loss 0.750	Accuracy 0.744
# Epoch: 6	Time 200.394
# Loss 0.957	Accuracy 0.703
# Epoch: 7	Time 229.033
# Loss 0.777	Accuracy 0.751
# Epoch: 8	Time 257.673
# Loss 0.822	Accuracy 0.755
# Epoch: 9	Time 286.361
# Loss 1.002	Accuracy 0.730
# Epoch: 10	Time 315.059
# Loss 1.059	Accuracy 0.723
# Epoch: 11	Time 343.740
# Loss 1.041	Accuracy 0.742
# Epoch: 12	Time 372.434
# Loss 1.024	Accuracy 0.753
# Epoch: 13	Time 401.150
# Loss 1.104	Accuracy 0.743
# Epoch: 14	Time 429.844
# Loss 1.245	Accuracy 0.732
# Epoch: 15	Time 458.538
# Loss 1.252	Accuracy 0.744
# Epoch: 16	Time 487.232
# Loss 1.261	Accuracy 0.744
# Epoch: 17	Time 515.936
# Loss 1.203	Accuracy 0.747
# Epoch: 18	Time 544.622
# Loss 1.239	Accuracy 0.757
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(accuracies)
plt.title('Validation accuracy');

# %%
plt.plot(losses)
plt.title('Validation loss');
